# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision
#import helper
import matplotlib.pyplot as plt

# torchvision package consists of popular datasets,
# model architectures, and common image transformations for computer vision.
from torchvision import datasets, transforms, models
#import torchvision.transforms as transforms
#import torchvision.datasets as datasets
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

train_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                      transforms.RandomRotation(30),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406] , [0.229, 0.224, 0.225])])

valid_transforms = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406] , [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406] , [0.229, 0.224, 0.225])])


# TODO: Load the datasets with ImageFolder
train_data = torchvision.datasets.ImageFolder(train_dir,transform=train_transforms)
valid_data = torchvision.datasets.ImageFolder(valid_dir,transform=valid_transforms)
test_data = torchvision.datasets.ImageFolder(test_dir,transform=test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size = 32, shuffle =True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size = 32, shuffle =False)
testloader = torch.utils.data.DataLoader(test_data, batch_size = 32, shuffle =False)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

# loading vgg16 model
model = models.vgg16(pretrained=True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:16<00:00, 34319357.89it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# freeze our features parameters
for param in model.parameters():
    param.requires_grades = False
    
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
    ('fcl', nn.Linear(25088, 512)), 
    ('relu', nn.ReLU()),
    ('do' , nn.Dropout(p=0.2)),
    ('fc2', nn.Linear(512,102)),
    ('output', nn.LogSoftmax(dim=1))
]))

model.classifier = classifier
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fcl): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU()
#     (do): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fcl): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU()
#     (do): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# Definition of a training function
def trainer_(epochs, steps, running_loss, print_every, training_dataset_loader, dataset_loader, _model):
    
    for epoch in range(epochs):
        
        for images, labels in training_dataset_loader:
            steps += 1
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            logps = _model(images)
            loss = criterion(logps, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            if steps % print_every == 0:
                _model.eval()
                dataset_loss = 0
                accuracy = 0
                
                for images, labels in dataset_loader:
                    images, labels = images.to(device), labels.to(device)
                    logps = _model(images)
                    loss = criterion(logps, labels)
                    dataset_loss += loss.item()
                    
                    #calculate our accuracy
                    ps = torch.exp(logps)
                    top_ps, top_class = ps.topk(1, dim=1)
                    equality = top_class == labels.view(*top_class.shape)
                    accuracy += torch.mean(equality.type(torch.FloatTensor)).item()
                    
                    print(f"Epoch {epoch+1}/{epochs}.. "
                          f"Train loss: {running_loss/print_every: .3f}).."
                          f"Valid loss: {dataset_loss/len(dataset_loader): .3f}.."
                          f"Valid accuracy: {accuracy/len(dataset_loader):.3f}")
                    
                    running_loss = 0
                    _model.train()

# %%
trainer_(epochs = 3, steps = 0, running_loss = 0, print_every = 60, training_dataset_loader = trainloader, dataset_loader = validloader, _model = model)
# Out:
# Epoch 1/3.. Train loss:  4.092)..Valid loss:  0.135..Valid accuracy: 0.011
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.257..Valid accuracy: 0.023
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.392..Valid accuracy: 0.036
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.491..Valid accuracy: 0.054
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.611..Valid accuracy: 0.064
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.789..Valid accuracy: 0.066
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.895..Valid accuracy: 0.081
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.009..Valid accuracy: 0.090
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.088..Valid accuracy: 0.109
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.252..Valid accuracy: 0.114
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.380..Valid accuracy: 0.124
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.542..Valid accuracy: 0.124
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.615..Valid accuracy: 0.148
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.711..Valid accuracy: 0.168
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.817..Valid accuracy: 0.181
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.947..Valid accuracy: 0.188
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.034..Valid accuracy: 0.206
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.142..Valid accuracy: 0.221
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.184..Valid accuracy: 0.254
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.237..Valid accuracy: 0.279
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.346..Valid accuracy: 0.286
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.496..Valid accuracy: 0.290
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.557..Valid accuracy: 0.310
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.713..Valid accuracy: 0.314
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  2.857..Valid accuracy: 0.316
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  3.010..Valid accuracy: 0.316
# Epoch 1/3.. Train loss:  2.820)..Valid loss:  0.124..Valid accuracy: 0.008
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.217..Valid accuracy: 0.017
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.322..Valid accuracy: 0.034
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.412..Valid accuracy: 0.048
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.488..Valid accuracy: 0.066
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.593..Valid accuracy: 0.076
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.693..Valid accuracy: 0.091
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.767..Valid accuracy: 0.108
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.822..Valid accuracy: 0.133
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.905..Valid accuracy: 0.147
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.012..Valid accuracy: 0.159
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.092..Valid accuracy: 0.177
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.137..Valid accuracy: 0.204
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.190..Valid accuracy: 0.228
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.256..Valid accuracy: 0.245
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.345..Valid accuracy: 0.262
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.397..Valid accuracy: 0.286
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.435..Valid accuracy: 0.320
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.450..Valid accuracy: 0.355
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.483..Valid accuracy: 0.387
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.554..Valid accuracy: 0.404
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.637..Valid accuracy: 0.421
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.674..Valid accuracy: 0.452
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.774..Valid accuracy: 0.470
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.875..Valid accuracy: 0.481
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.929..Valid accuracy: 0.509
# Epoch 1/3.. Train loss:  2.228)..Valid loss:  0.080..Valid accuracy: 0.017
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.131..Valid accuracy: 0.042
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.208..Valid accuracy: 0.065
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.271..Valid accuracy: 0.085
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.333..Valid accuracy: 0.107
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.405..Valid accuracy: 0.123
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.476..Valid accuracy: 0.143
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.558..Valid accuracy: 0.161
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.615..Valid accuracy: 0.180
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.671..Valid accuracy: 0.200
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.744..Valid accuracy: 0.219
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.802..Valid accuracy: 0.242
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.829..Valid accuracy: 0.275
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.874..Valid accuracy: 0.304
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.913..Valid accuracy: 0.331
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.970..Valid accuracy: 0.355
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.994..Valid accuracy: 0.388
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.021..Valid accuracy: 0.422
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.045..Valid accuracy: 0.451
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.076..Valid accuracy: 0.482
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.136..Valid accuracy: 0.502
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.214..Valid accuracy: 0.517
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.269..Valid accuracy: 0.541
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.345..Valid accuracy: 0.562
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.432..Valid accuracy: 0.576
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.520..Valid accuracy: 0.591
# Epoch 2/3.. Train loss:  1.925)..Valid loss:  0.061..Valid accuracy: 0.022
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.129..Valid accuracy: 0.042
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.190..Valid accuracy: 0.066
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.246..Valid accuracy: 0.090
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.292..Valid accuracy: 0.115
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.370..Valid accuracy: 0.127
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.452..Valid accuracy: 0.147
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.547..Valid accuracy: 0.162
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.593..Valid accuracy: 0.189
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.655..Valid accuracy: 0.213
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.711..Valid accuracy: 0.234
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.774..Valid accuracy: 0.252
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.805..Valid accuracy: 0.281
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.844..Valid accuracy: 0.306
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.878..Valid accuracy: 0.334
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.934..Valid accuracy: 0.356
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.974..Valid accuracy: 0.381
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.013..Valid accuracy: 0.411
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.020..Valid accuracy: 0.445
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.056..Valid accuracy: 0.475
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.121..Valid accuracy: 0.492
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.186..Valid accuracy: 0.516
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.216..Valid accuracy: 0.547
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.320..Valid accuracy: 0.566
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.417..Valid accuracy: 0.581
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.467..Valid accuracy: 0.606
# Epoch 2/3.. Train loss:  1.718)..Valid loss:  0.050..Valid accuracy: 0.024
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.104..Valid accuracy: 0.044
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.157..Valid accuracy: 0.069
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.218..Valid accuracy: 0.094
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.290..Valid accuracy: 0.113
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.377..Valid accuracy: 0.124
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.451..Valid accuracy: 0.145
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.501..Valid accuracy: 0.167
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.546..Valid accuracy: 0.195
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.581..Valid accuracy: 0.221
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.649..Valid accuracy: 0.242
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.700..Valid accuracy: 0.268
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.718..Valid accuracy: 0.302
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.734..Valid accuracy: 0.337
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.778..Valid accuracy: 0.359
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.815..Valid accuracy: 0.388
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.848..Valid accuracy: 0.418
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.888..Valid accuracy: 0.446
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.919..Valid accuracy: 0.477
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.940..Valid accuracy: 0.511
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.993..Valid accuracy: 0.531
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.086..Valid accuracy: 0.546
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.148..Valid accuracy: 0.567
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.224..Valid accuracy: 0.590
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.314..Valid accuracy: 0.605
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.376..Valid accuracy: 0.628
# Epoch 2/3.. Train loss:  1.682)..Valid loss:  0.040..Valid accuracy: 0.025
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.083..Valid accuracy: 0.050
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.141..Valid accuracy: 0.073
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.167..Valid accuracy: 0.103
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.210..Valid accuracy: 0.130
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.260..Valid accuracy: 0.156
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.332..Valid accuracy: 0.179
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.407..Valid accuracy: 0.200
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.478..Valid accuracy: 0.220
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.518..Valid accuracy: 0.249
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.573..Valid accuracy: 0.270
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.643..Valid accuracy: 0.292
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.663..Valid accuracy: 0.323
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.684..Valid accuracy: 0.352
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.721..Valid accuracy: 0.381
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.771..Valid accuracy: 0.404
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.799..Valid accuracy: 0.431
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.819..Valid accuracy: 0.464
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.832..Valid accuracy: 0.496
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.845..Valid accuracy: 0.532
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.906..Valid accuracy: 0.555
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.968..Valid accuracy: 0.579
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.000..Valid accuracy: 0.608
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.067..Valid accuracy: 0.638
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.142..Valid accuracy: 0.655
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.178..Valid accuracy: 0.689
# Epoch 3/3.. Train loss:  1.686)..Valid loss:  0.046..Valid accuracy: 0.024
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.095..Valid accuracy: 0.048
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.133..Valid accuracy: 0.078
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.178..Valid accuracy: 0.100
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.232..Valid accuracy: 0.123
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.311..Valid accuracy: 0.142
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.364..Valid accuracy: 0.165
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.418..Valid accuracy: 0.190
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.464..Valid accuracy: 0.218
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.487..Valid accuracy: 0.250
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.528..Valid accuracy: 0.273
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.587..Valid accuracy: 0.292
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.599..Valid accuracy: 0.328
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.612..Valid accuracy: 0.364
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.643..Valid accuracy: 0.394
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.680..Valid accuracy: 0.424
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.713..Valid accuracy: 0.453
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.732..Valid accuracy: 0.487
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.744..Valid accuracy: 0.519
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.763..Valid accuracy: 0.553
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.825..Valid accuracy: 0.570
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.875..Valid accuracy: 0.595
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.902..Valid accuracy: 0.627
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.971..Valid accuracy: 0.654
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.058..Valid accuracy: 0.667
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.093..Valid accuracy: 0.697
# Epoch 3/3.. Train loss:  1.462)..Valid loss:  0.043..Valid accuracy: 0.026
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.085..Valid accuracy: 0.055
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.116..Valid accuracy: 0.088
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.140..Valid accuracy: 0.119
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.194..Valid accuracy: 0.142
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.248..Valid accuracy: 0.166
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.297..Valid accuracy: 0.194
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.354..Valid accuracy: 0.218
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.382..Valid accuracy: 0.246
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.404..Valid accuracy: 0.278
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.446..Valid accuracy: 0.302
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.506..Valid accuracy: 0.325
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.526..Valid accuracy: 0.357
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.542..Valid accuracy: 0.389
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.549..Valid accuracy: 0.425
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.574..Valid accuracy: 0.457
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.601..Valid accuracy: 0.486
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.640..Valid accuracy: 0.517
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.666..Valid accuracy: 0.547
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.698..Valid accuracy: 0.578
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.758..Valid accuracy: 0.599
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.814..Valid accuracy: 0.619
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.842..Valid accuracy: 0.650
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.921..Valid accuracy: 0.674
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.011..Valid accuracy: 0.690
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.036..Valid accuracy: 0.720
# Epoch 3/3.. Train loss:  1.532)..Valid loss:  0.034..Valid accuracy: 0.028
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.089..Valid accuracy: 0.053
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.125..Valid accuracy: 0.083
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.155..Valid accuracy: 0.115
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.182..Valid accuracy: 0.145
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.252..Valid accuracy: 0.168
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.307..Valid accuracy: 0.191
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.353..Valid accuracy: 0.212
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.378..Valid accuracy: 0.244
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.423..Valid accuracy: 0.273
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.455..Valid accuracy: 0.302
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.482..Valid accuracy: 0.333
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.494..Valid accuracy: 0.367
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.518..Valid accuracy: 0.398
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.531..Valid accuracy: 0.430
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.566..Valid accuracy: 0.457
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.613..Valid accuracy: 0.481
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.634..Valid accuracy: 0.516
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.650..Valid accuracy: 0.548
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.671..Valid accuracy: 0.578
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.700..Valid accuracy: 0.607
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.739..Valid accuracy: 0.633
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.756..Valid accuracy: 0.668
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.833..Valid accuracy: 0.692
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.903..Valid accuracy: 0.710
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.939..Valid accuracy: 0.740
# Epoch 3/3.. Train loss:  1.490)..Valid loss:  0.048..Valid accuracy: 0.025
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.074..Valid accuracy: 0.055
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.107..Valid accuracy: 0.087
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.143..Valid accuracy: 0.115
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.215..Valid accuracy: 0.137
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.271..Valid accuracy: 0.163
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.326..Valid accuracy: 0.188
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.386..Valid accuracy: 0.210
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.422..Valid accuracy: 0.239
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.462..Valid accuracy: 0.266
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.488..Valid accuracy: 0.296
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.530..Valid accuracy: 0.323
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.551..Valid accuracy: 0.355
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.569..Valid accuracy: 0.388
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.599..Valid accuracy: 0.418
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.629..Valid accuracy: 0.446
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.652..Valid accuracy: 0.477
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.655..Valid accuracy: 0.514
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.685..Valid accuracy: 0.543
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.702..Valid accuracy: 0.577
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.773..Valid accuracy: 0.593
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.820..Valid accuracy: 0.618
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.863..Valid accuracy: 0.647
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.954..Valid accuracy: 0.672
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.995..Valid accuracy: 0.696
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.019..Valid accuracy: 0.730

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
trainer_(epochs = 3, steps = 0, running_loss = 0, print_every = 60, training_dataset_loader = trainloader, dataset_loader = testloader, _model = model)
# Out:
# Epoch 1/3.. Train loss:  1.277)..Valid loss:  0.030..Valid accuracy: 0.029
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.078..Valid accuracy: 0.055
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.120..Valid accuracy: 0.085
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.155..Valid accuracy: 0.117
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.201..Valid accuracy: 0.142
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.224..Valid accuracy: 0.174
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.327..Valid accuracy: 0.195
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.383..Valid accuracy: 0.218
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.394..Valid accuracy: 0.254
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.429..Valid accuracy: 0.281
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.488..Valid accuracy: 0.306
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.523..Valid accuracy: 0.335
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.549..Valid accuracy: 0.368
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.576..Valid accuracy: 0.399
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.622..Valid accuracy: 0.425
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.666..Valid accuracy: 0.448
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.710..Valid accuracy: 0.476
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.713..Valid accuracy: 0.514
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.724..Valid accuracy: 0.548
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.738..Valid accuracy: 0.583
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.791..Valid accuracy: 0.606
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.843..Valid accuracy: 0.626
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.886..Valid accuracy: 0.651
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.946..Valid accuracy: 0.675
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.036..Valid accuracy: 0.692
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.104..Valid accuracy: 0.715
# Epoch 1/3.. Train loss:  1.380)..Valid loss:  0.038..Valid accuracy: 0.028
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.091..Valid accuracy: 0.053
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.138..Valid accuracy: 0.077
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.180..Valid accuracy: 0.101
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.256..Valid accuracy: 0.124
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.284..Valid accuracy: 0.154
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.341..Valid accuracy: 0.179
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.401..Valid accuracy: 0.200
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.419..Valid accuracy: 0.236
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.467..Valid accuracy: 0.261
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.535..Valid accuracy: 0.280
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.576..Valid accuracy: 0.308
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.605..Valid accuracy: 0.343
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.625..Valid accuracy: 0.376
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.681..Valid accuracy: 0.406
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.707..Valid accuracy: 0.438
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.740..Valid accuracy: 0.468
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.742..Valid accuracy: 0.505
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.754..Valid accuracy: 0.538
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.764..Valid accuracy: 0.573
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.819..Valid accuracy: 0.596
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.852..Valid accuracy: 0.626
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.922..Valid accuracy: 0.647
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.004..Valid accuracy: 0.666
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.079..Valid accuracy: 0.685
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.158..Valid accuracy: 0.713
# Epoch 1/3.. Train loss:  1.391)..Valid loss:  0.038..Valid accuracy: 0.024
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.087..Valid accuracy: 0.049
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.116..Valid accuracy: 0.078
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.156..Valid accuracy: 0.102
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.202..Valid accuracy: 0.127
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.233..Valid accuracy: 0.157
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.322..Valid accuracy: 0.174
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.352..Valid accuracy: 0.203
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.378..Valid accuracy: 0.234
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.393..Valid accuracy: 0.269
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.464..Valid accuracy: 0.290
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.502..Valid accuracy: 0.319
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.542..Valid accuracy: 0.349
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.558..Valid accuracy: 0.381
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.620..Valid accuracy: 0.409
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.650..Valid accuracy: 0.438
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.674..Valid accuracy: 0.468
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.676..Valid accuracy: 0.506
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.688..Valid accuracy: 0.538
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.710..Valid accuracy: 0.571
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.785..Valid accuracy: 0.593
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.827..Valid accuracy: 0.619
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.872..Valid accuracy: 0.647
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.938..Valid accuracy: 0.668
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  0.984..Valid accuracy: 0.692
# Epoch 1/3.. Train loss:  0.000)..Valid loss:  1.052..Valid accuracy: 0.719
# Epoch 2/3.. Train loss:  1.283)..Valid loss:  0.058..Valid accuracy: 0.020
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.114..Valid accuracy: 0.042
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.168..Valid accuracy: 0.062
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.207..Valid accuracy: 0.088
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.253..Valid accuracy: 0.114
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.288..Valid accuracy: 0.142
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.362..Valid accuracy: 0.162
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.393..Valid accuracy: 0.192
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.420..Valid accuracy: 0.224
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.466..Valid accuracy: 0.249
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.568..Valid accuracy: 0.264
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.600..Valid accuracy: 0.294
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.605..Valid accuracy: 0.332
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.626..Valid accuracy: 0.363
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.670..Valid accuracy: 0.392
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.723..Valid accuracy: 0.416
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.758..Valid accuracy: 0.445
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.761..Valid accuracy: 0.483
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.767..Valid accuracy: 0.519
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.787..Valid accuracy: 0.553
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.868..Valid accuracy: 0.571
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.927..Valid accuracy: 0.596
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.957..Valid accuracy: 0.625
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.016..Valid accuracy: 0.650
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.066..Valid accuracy: 0.674
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.131..Valid accuracy: 0.699
# Epoch 2/3.. Train loss:  1.246)..Valid loss:  0.034..Valid accuracy: 0.030
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.072..Valid accuracy: 0.054
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.100..Valid accuracy: 0.082
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.119..Valid accuracy: 0.113
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.176..Valid accuracy: 0.137
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.205..Valid accuracy: 0.167
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.289..Valid accuracy: 0.188
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.330..Valid accuracy: 0.214
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.363..Valid accuracy: 0.243
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.407..Valid accuracy: 0.270
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.501..Valid accuracy: 0.287
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.532..Valid accuracy: 0.317
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.548..Valid accuracy: 0.351
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.562..Valid accuracy: 0.386
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.621..Valid accuracy: 0.413
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.664..Valid accuracy: 0.442
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.692..Valid accuracy: 0.472
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.694..Valid accuracy: 0.511
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.704..Valid accuracy: 0.546
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.715..Valid accuracy: 0.581
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.782..Valid accuracy: 0.605
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.837..Valid accuracy: 0.630
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.864..Valid accuracy: 0.657
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.899..Valid accuracy: 0.686
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.972..Valid accuracy: 0.704
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.049..Valid accuracy: 0.727
# Epoch 2/3.. Train loss:  1.290)..Valid loss:  0.019..Valid accuracy: 0.031
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.074..Valid accuracy: 0.058
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.101..Valid accuracy: 0.089
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.122..Valid accuracy: 0.117
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.181..Valid accuracy: 0.142
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.206..Valid accuracy: 0.171
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.289..Valid accuracy: 0.191
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.350..Valid accuracy: 0.216
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.386..Valid accuracy: 0.244
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.418..Valid accuracy: 0.276
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.516..Valid accuracy: 0.294
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.552..Valid accuracy: 0.321
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.558..Valid accuracy: 0.358
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.571..Valid accuracy: 0.393
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.626..Valid accuracy: 0.419
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.648..Valid accuracy: 0.450
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.672..Valid accuracy: 0.482
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.673..Valid accuracy: 0.520
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.684..Valid accuracy: 0.554
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.716..Valid accuracy: 0.585
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.768..Valid accuracy: 0.609
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.797..Valid accuracy: 0.637
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.836..Valid accuracy: 0.663
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.895..Valid accuracy: 0.690
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  0.970..Valid accuracy: 0.710
# Epoch 2/3.. Train loss:  0.000)..Valid loss:  1.044..Valid accuracy: 0.733
# Epoch 3/3.. Train loss:  1.219)..Valid loss:  0.026..Valid accuracy: 0.026
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.053..Valid accuracy: 0.058
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.087..Valid accuracy: 0.084
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.122..Valid accuracy: 0.109
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.187..Valid accuracy: 0.135
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.208..Valid accuracy: 0.167
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.291..Valid accuracy: 0.188
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.343..Valid accuracy: 0.218
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.361..Valid accuracy: 0.250
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.393..Valid accuracy: 0.281
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.450..Valid accuracy: 0.303
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.473..Valid accuracy: 0.335
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.513..Valid accuracy: 0.370
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.532..Valid accuracy: 0.403
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.587..Valid accuracy: 0.433
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.606..Valid accuracy: 0.466
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.637..Valid accuracy: 0.500
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.637..Valid accuracy: 0.538
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.641..Valid accuracy: 0.576
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.657..Valid accuracy: 0.609
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.708..Valid accuracy: 0.636
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.750..Valid accuracy: 0.659
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.793..Valid accuracy: 0.686
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.852..Valid accuracy: 0.709
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.900..Valid accuracy: 0.734
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.968..Valid accuracy: 0.759
# Epoch 3/3.. Train loss:  1.203)..Valid loss:  0.041..Valid accuracy: 0.024
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.087..Valid accuracy: 0.053
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.105..Valid accuracy: 0.087
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.141..Valid accuracy: 0.118
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.197..Valid accuracy: 0.136
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.228..Valid accuracy: 0.166
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.302..Valid accuracy: 0.190
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.351..Valid accuracy: 0.219
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.375..Valid accuracy: 0.250
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.427..Valid accuracy: 0.276
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.522..Valid accuracy: 0.293
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.548..Valid accuracy: 0.322
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.561..Valid accuracy: 0.357
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.577..Valid accuracy: 0.389
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.622..Valid accuracy: 0.417
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.658..Valid accuracy: 0.448
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.669..Valid accuracy: 0.482
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.671..Valid accuracy: 0.520
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.676..Valid accuracy: 0.556
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.695..Valid accuracy: 0.590
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.734..Valid accuracy: 0.621
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.773..Valid accuracy: 0.651
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.799..Valid accuracy: 0.680
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.853..Valid accuracy: 0.710
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.930..Valid accuracy: 0.733
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  1.026..Valid accuracy: 0.751
# Epoch 3/3.. Train loss:  1.199)..Valid loss:  0.028..Valid accuracy: 0.030
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.063..Valid accuracy: 0.060
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.093..Valid accuracy: 0.090
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.118..Valid accuracy: 0.119
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.170..Valid accuracy: 0.143
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.186..Valid accuracy: 0.177
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.267..Valid accuracy: 0.198
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.311..Valid accuracy: 0.228
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.326..Valid accuracy: 0.266
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.367..Valid accuracy: 0.296
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.437..Valid accuracy: 0.317
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.458..Valid accuracy: 0.347
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.478..Valid accuracy: 0.382
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.497..Valid accuracy: 0.415
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.561..Valid accuracy: 0.442
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.588..Valid accuracy: 0.471
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.601..Valid accuracy: 0.505
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.607..Valid accuracy: 0.541
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.612..Valid accuracy: 0.578
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.645..Valid accuracy: 0.612
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.718..Valid accuracy: 0.633
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.769..Valid accuracy: 0.657
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.798..Valid accuracy: 0.686
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.863..Valid accuracy: 0.710
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.915..Valid accuracy: 0.736
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.998..Valid accuracy: 0.762
# Epoch 3/3.. Train loss:  1.318)..Valid loss:  0.033..Valid accuracy: 0.026
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.072..Valid accuracy: 0.053
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.117..Valid accuracy: 0.079
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.154..Valid accuracy: 0.108
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.205..Valid accuracy: 0.131
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.230..Valid accuracy: 0.165
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.300..Valid accuracy: 0.185
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.358..Valid accuracy: 0.212
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.376..Valid accuracy: 0.244
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.411..Valid accuracy: 0.275
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.478..Valid accuracy: 0.296
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.505..Valid accuracy: 0.326
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.529..Valid accuracy: 0.361
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.543..Valid accuracy: 0.394
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.596..Valid accuracy: 0.424
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.618..Valid accuracy: 0.454
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.637..Valid accuracy: 0.488
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.639..Valid accuracy: 0.525
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.648..Valid accuracy: 0.559
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.666..Valid accuracy: 0.593
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.701..Valid accuracy: 0.626
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.738..Valid accuracy: 0.655
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.762..Valid accuracy: 0.688
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.816..Valid accuracy: 0.712
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.855..Valid accuracy: 0.739
# Epoch 3/3.. Train loss:  0.000)..Valid loss:  0.931..Valid accuracy: 0.761

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx
print("Our model: \n\n", model, '\n')
print("The state dict keys: \n\n", model.state_dict().keys())
# Out:
# Our model:
#
#  VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fcl): Linear(in_features=25088, out_features=512, bias=True)
#     (relu): ReLU()
#     (do): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )
#
# The state dict keys:
#
#  odict_keys(['features.0.weight', 'features.0.bias', 'features.2.weight', 'features.2.bias', 'features.5.weight', 'features.5.bias', 'features.7.weight', 'features.7.bias', 'features.10.weight', 'features.10.bias', 'features.12.weight', 'features.12.bias', 'features.14.weight', 'features.14.bias', 'features.17.weight', 'features.17.bias', 'features.19.weight', 'features.19.bias', 'features.21.weight', 'features.21.bias', 'features.24.weight', 'features.24.bias', 'features.26.weight', 'features.26.bias', 'features.28.weight', 'features.28.bias', 'classifier.fcl.weight', 'classifier.fcl.bias', 'classifier.fc2.weight', 'classifier.fc2.bias'])

# %%
checkpoint = { 'epochs' : 3,
                'arch': 'vgg16',
               'classifier': model.classifier,
               'state_dict': model.state_dict(),
              'optimizer_state_dict': optimizer.state_dict(),
               'class_to_idx' : model.class_to_idx}

torch.save(checkpoint, 'vgg16_checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    model = models.vgg16(pretrained = True)
    # freeze our features parameters
    for param in model.parameters():
        param.requires_grades = False
    # Allow classifier parameters
    #for param in classifier.parameters():
    #    param.requires_grades = True    
    #use our other coponents of the trained model
    model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
   
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
       
    # TODO: Process a PIL image for use in a PyTorch model
    im = Image.open(image)
    
    # 1.resize the given image
    #with Image.open("hopper.jpg") as im:

    # Provide the target width and height of the image
    (width, height) = (256, 256)
    im_resized = im.resize((width, height))
    
    #2.crop out the center 224x224 portion of the image
    half_crop = (256-224)*0.5
    right, lower = im_resized.size
    im_crop = im_resized.crop((half_crop, half_crop, right - half_crop, lower - half_crop))
    
    #3. Convert Color channels of images from 0-255 to 0-1
    np_image = np.array(im_crop)/255
    
    #4.Normalize the image 
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    image = (np_image-mean)/std
    
    #5.Reorder dimensions for the color channel to be the first dimension 
    image = image.transpose(2,0,1)
    
    return image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
imshow(torch.from_numpy(process_image('./flowers/train/1/image_06734.jpg')))
##imshow(process_image(img))

#imshow(process_image('flowers/train/10/image_07087.jpg'))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    
    #process numpy image
    image = torch.from_numpy(process_image(image_path))
    model.to(device)
    model.eval()
    #image = process_image(image_path)
    image.type(torch.FloatTensor)
    image = image.unsqueeze(0)
    inputs = image.to(device)
    #output = model.forward(inputs)
    #image = image.unsqueeze_(0)
    log_ps = model(image)
    lin_ps = torch.exp(log_ps)
    top_p, top_classes = lin_ps.topk(topk)
    #top_ps, top_class = ps.topk(1, dim=1)
    #probs, indices = output.topk(topk)
    #class_to_idx = {value:key for key,value in class_to_idx.iteritems()}
    return top_p, top_classes

# %%
model=load_checkpoint('vgg16_checkpoint.pth')
image_path = './flowers/train/1/image_06734.jpg'                              
predict(image_path,model)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-c2b3b5c695d3> in <module>()
#       1 model=load_checkpoint('vgg16_checkpoint.pth')
#       2 image_path = './flowers/train/1/image_06734.jpg'
# ----> 3 predict(image_path,model)
#
# <ipython-input-22-0e6e080dd07d> in predict(image_path, model, topk)
#      15     #output = model.forward(inputs)
#      16     #image = image.unsqueeze_(0)
# ---> 17     log_ps = model(image)
#      18     lin_ps = torch.exp(log_ps)
#      19     top_p, top_classes = lin_ps.topk(topk)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/vgg.py in forward(self, x)
#      40
#      41     def forward(self, x):
# ---> 42         x = self.features(x)
#      43         x = x.view(x.size(0), -1)
#      44         x = self.classifier(x)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# RuntimeError: Expected object of type torch.DoubleTensor but found type torch.cuda.FloatTensor for argument #2 'weight'

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
